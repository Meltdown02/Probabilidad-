# %% [markdown]
# <a href="https://colab.research.google.com/github/Meltdown02/Probabilidad-/blob/main/Unidad2/probabilidad_U2_Programa3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**PROBABILIDAD Y ESTADISTICA**
# ##PRACTICA 3: PERMUTACIONES EN PYTHON ##
# ##UNIDAD 2 ##
# **FACILITADOR: DR JOSE GABRIEL RODRIGUEZ RIVAS**
#
# **ALUMNO: MARCO ANTONIO AGUILAR RUIZ**

# %%
import math as mt
from itertools import permutations

# %%
asistentes = ["A1", "A2", "A3", "A4", "A5",
              "A6", "A7", "A8", "A9", "A10"]

n = len(asistentes)
r = 4

Pr = mt.factorial(n) / (mt.factorial(n-r))

print("Existen ", Pr, " posibles permutaciones sin repetición del total de ",
      n, " asistentes", " en grupos de ", r, " en ", r)

print("Aquí las permutaciones")
permutaciones_asistentes = list(permutations(asistentes, r))


for permutacion in permutaciones_asistentes:
    print(permutacion)
# Out:
# Existen  5040.0  posibles permutaciones sin repetición del total de  10  asistentes  en grupos de  4  en  4
# Aquí las permutaciones
# ('A1', 'A2', 'A3', 'A4')
# ('A1', 'A2', 'A3', 'A5')
# ('A1', 'A2', 'A3', 'A6')
# ('A1', 'A2', 'A3', 'A7')
# ('A1', 'A2', 'A3', 'A8')
# ('A1', 'A2', 'A3', 'A9')
# ('A1', 'A2', 'A3', 'A10')
# ('A1', 'A2', 'A4', 'A3')
# ('A1', 'A2', 'A4', 'A5')
# ('A1', 'A2', 'A4', 'A6')
# ('A1', 'A2', 'A4', 'A7')
# ('A1', 'A2', 'A4', 'A8')
# ('A1', 'A2', 'A4', 'A9')
# ('A1', 'A2', 'A4', 'A10')
# ('A1', 'A2', 'A5', 'A3')
# ('A1', 'A2', 'A5', 'A4')
# ('A1', 'A2', 'A5', 'A6')
# ('A1', 'A2', 'A5', 'A7')
# ('A1', 'A2', 'A5', 'A8')
# ('A1', 'A2', 'A5', 'A9')
# ('A1', 'A2', 'A5', 'A10')
# ('A1', 'A2', 'A6', 'A3')
# ('A1', 'A2', 'A6', 'A4')
# ('A1', 'A2', 'A6', 'A5')
# ('A1', 'A2', 'A6', 'A7')
# ('A1', 'A2', 'A6', 'A8')
# ('A1', 'A2', 'A6', 'A9')
# ('A1', 'A2', 'A6', 'A10')
# ('A1', 'A2', 'A7', 'A3')
# ('A1', 'A2', 'A7', 'A4')
# ('A1', 'A2', 'A7', 'A5')
# ...
